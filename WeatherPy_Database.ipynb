# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import time

import matplotlib.pyplot as plt
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=071a9b7f20d73f3590e397c7e43f09b7

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_weather_description})
                         

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 2 of Set 1 | clyde river
# Processing Record 3 of Set 1 | kyaikto
# Processing Record 4 of Set 1 | constitucion
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | lompoc
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | santa quiteria
# Processing Record 11 of Set 1 | lagoa
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | tucupita
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | jinchang
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | valparaiso
# Processing Record 21 of Set 1 | alytus
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | peremyshlyany
# Processing Record 24 of Set 1 | gat
# Processing Record 25 of Set 1 | teknaf
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | totness
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | odweyne
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | beyneu
# Processing Record 33 of Set 1 | atar
# Processing Record 34 of Set 1 | kizema
# Processing Record 35 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 1 | burns lake
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | aranjuez
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | tarko-sale
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | singaparna
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 1 | cadiz
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | solwezi
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | nelson bay
# Processing Record 4 of Set 2 | katsuura
# Processing Record 5 of Set 2 | itanagar
# Processing Record 6 of Set 2 | tigzirt
# Processing Record 7 of Set 2 | port hedland
# Processing Record 8 of Set 2 | rawlins
# Processing Record 9 of Set 2 | codrington
# Processing Record 10 of Set 2 | arlit
# Processing Record 11 of Set 2 | tubuala
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | priargunsk
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | garh maharaja
# Processing Record 17 of Set 2 | pisco
# Processing Record 18 of Set 2 | nishihara
# Processing Record 19 of Set 2 | alofi
# Processing Record 20 of Set 2 | cururupu
# Processing Record 21 of Set 2 | freeport
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | margate
# Processing Record 24 of Set 2 | luang prabang
# Processing Record 25 of Set 2 | lorengau
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | upata
# Processing Record 29 of Set 2 | filadelfia
# Processing Record 30 of Set 2 | tamandare
# Processing Record 31 of Set 2 | dukat
# Processing Record 32 of Set 2 | vila velha
# Processing Record 33 of Set 2 | baruun-urt
# Processing Record 34 of Set 2 | la ronge
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | kainantu
# Processing Record 37 of Set 2 | fairbanks
# Processing Record 38 of Set 2 | college
# Processing Record 39 of Set 2 | saldanha
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | stara vyzhivka
# Processing Record 43 of Set 2 | kavaratti
# Processing Record 44 of Set 2 | hvolsvollur
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | flin flon
# Processing Record 47 of Set 2 | mandalgovi
# Processing Record 48 of Set 2 | grafton
# Processing Record 49 of Set 2 | punta arenas
# Processing Record 50 of Set 2 | brae
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | tucuman
# Processing Record 4 of Set 3 | dharchula
# Processing Record 5 of Set 3 | diplo
# Processing Record 6 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 7 of Set 3 | vychegodskiy
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | posevnaya
# Processing Record 10 of Set 3 | tual
# Processing Record 11 of Set 3 | brive-la-gaillarde
# Processing Record 12 of Set 3 | uch
# Processing Record 13 of Set 3 | garissa
# Processing Record 14 of Set 3 | kudahuvadhoo
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | ayagoz
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | ferrol
# Processing Record 21 of Set 3 | half moon bay
# Processing Record 22 of Set 3 | atuona
# Processing Record 23 of Set 3 | antofagasta
# Processing Record 24 of Set 3 | ziro
# Processing Record 25 of Set 3 | sinnamary
# Processing Record 26 of Set 3 | micheweni
# Processing Record 27 of Set 3 | sokolo
# Processing Record 28 of Set 3 | asau
# Processing Record 29 of Set 3 | los llanos de aridane
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | agua dulce
# Processing Record 32 of Set 3 | san cristobal
# Processing Record 33 of Set 3 | chimoio
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | ketchikan
# Processing Record 36 of Set 3 | henties bay
# Processing Record 37 of Set 3 | danshui
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | florianopolis
# Processing Record 40 of Set 3 | taft
# Processing Record 41 of Set 3 | miramar
# Processing Record 42 of Set 3 | praia da vitoria
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | damghan
# Processing Record 46 of Set 3 | peniche
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | pointe michel
# Processing Record 49 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 3 | vaini
# Processing Record 1 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | port huron
# Processing Record 4 of Set 4 | saint-pierre
# Processing Record 5 of Set 4 | paamiut
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | mataura
# Processing Record 8 of Set 4 | butaritari
# Processing Record 9 of Set 4 | hauterive
# Processing Record 10 of Set 4 | moengo
# Processing Record 11 of Set 4 | luena
# Processing Record 12 of Set 4 | bathsheba
# Processing Record 13 of Set 4 | slough
# Processing Record 14 of Set 4 | east london
# Processing Record 15 of Set 4 | mackay
# Processing Record 16 of Set 4 | qingdao
# Processing Record 17 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 4 | te anau
# Processing Record 19 of Set 4 | chuy
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | mahebourg
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | tutoia
# Processing Record 24 of Set 4 | bengkulu
# Processing Record 25 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 4 | saskylakh
# Processing Record 27 of Set 4 | mantua
# Processing Record 28 of Set 4 | carutapera
# Processing Record 29 of Set 4 | norman wells
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | altamira
# Processing Record 32 of Set 4 | skjervoy
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | kalmunai
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | vuktyl
# Processing Record 37 of Set 4 | xingcheng
# Processing Record 38 of Set 4 | port alfred
# Processing Record 39 of Set 4 | hortobagy
# Processing Record 40 of Set 4 | kargasok
# Processing Record 41 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | roald
# Processing Record 45 of Set 4 | pontianak
# Processing Record 46 of Set 4 | ibiapina
# Processing Record 47 of Set 4 | gilazi
# City not found. Skipping...
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | anadyr
# Processing Record 50 of Set 4 | bolobo
# Processing Record 1 of Set 5 | vila franca do campo
# Processing Record 2 of Set 5 | hammerfest
# Processing Record 3 of Set 5 | ust-tsilma
# Processing Record 4 of Set 5 | tangshan
# Processing Record 5 of Set 5 | shingu
# Processing Record 6 of Set 5 | oktyabrskoye
# Processing Record 7 of Set 5 | grand gaube
# Processing Record 8 of Set 5 | vanimo
# Processing Record 9 of Set 5 | colac
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | beloha
# Processing Record 12 of Set 5 | smithers
# Processing Record 13 of Set 5 | husavik
# Processing Record 14 of Set 5 | sorong
# Processing Record 15 of Set 5 | manbij
# Processing Record 16 of Set 5 | mugur-aksy
# Processing Record 17 of Set 5 | sonoita
# Processing Record 18 of Set 5 | miyoshi
# Processing Record 19 of Set 5 | the pas
# Processing Record 20 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 21 of Set 5 | barrow
# Processing Record 22 of Set 5 | porto de moz
# Processing Record 23 of Set 5 | cabedelo
# Processing Record 24 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 5 | alamogordo
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | lekoni
# Processing Record 28 of Set 5 | ranong
# Processing Record 29 of Set 5 | dubenskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | kommunar
# Processing Record 31 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 5 | tateyama
# Processing Record 33 of Set 5 | cayenne
# Processing Record 34 of Set 5 | onega
# Processing Record 35 of Set 5 | durban
# Processing Record 36 of Set 5 | tuatapere
# Processing Record 37 of Set 5 | at-bashi
# Processing Record 38 of Set 5 | ponta delgada
# Processing Record 39 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 5 | bjornevatn
# Processing Record 41 of Set 5 | tura
# Processing Record 42 of Set 5 | praia
# Processing Record 43 of Set 5 | hualmay
# Processing Record 44 of Set 5 | davila
# Processing Record 45 of Set 5 | rio branco
# Processing Record 46 of Set 5 | salamanca
# Processing Record 47 of Set 5 | floro
# Processing Record 48 of Set 5 | lethem
# Processing Record 49 of Set 5 | bubaque
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | buraydah
# Processing Record 2 of Set 6 | paytug
# City not found. Skipping...
# Processing Record 3 of Set 6 | las palmas
# Processing Record 4 of Set 6 | huarmey
# Processing Record 5 of Set 6 | vao
# Processing Record 6 of Set 6 | kovdor
# Processing Record 7 of Set 6 | caucaia
# Processing Record 8 of Set 6 | taoudenni
# Processing Record 9 of Set 6 | baoro
# Processing Record 10 of Set 6 | el faiyum
# City not found. Skipping...
# Processing Record 11 of Set 6 | deputatskiy
# Processing Record 12 of Set 6 | humaita
# Processing Record 13 of Set 6 | qixingtai
# Processing Record 14 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 6 | wladyslawowo
# Processing Record 16 of Set 6 | tyumentsevo
# Processing Record 17 of Set 6 | miranda
# Processing Record 18 of Set 6 | portland
# Processing Record 19 of Set 6 | ostrovnoy
# Processing Record 20 of Set 6 | padang
# Processing Record 21 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 6 | hobyo
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | narsaq
# Processing Record 25 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 6 | kumbo
# Processing Record 27 of Set 6 | nsanje
# Processing Record 28 of Set 6 | muravlenko
# Processing Record 29 of Set 6 | pangody
# Processing Record 30 of Set 6 | zhaodong
# Processing Record 31 of Set 6 | shieli
# Processing Record 32 of Set 6 | adrar
# Processing Record 33 of Set 6 | veraval
# Processing Record 34 of Set 6 | wawa
# Processing Record 35 of Set 6 | nadvoitsy
# Processing Record 36 of Set 6 | enid
# Processing Record 37 of Set 6 | zaysan
# Processing Record 38 of Set 6 | decatur
# Processing Record 39 of Set 6 | berlevag
# Processing Record 40 of Set 6 | ye
# City not found. Skipping...
# Processing Record 41 of Set 6 | chernyshevskiy
# Processing Record 42 of Set 6 | barra do garcas
# Processing Record 43 of Set 6 | morehead
# Processing Record 44 of Set 6 | nanortalik
# Processing Record 45 of Set 6 | chicama
# Processing Record 46 of Set 6 | burnie
# Processing Record 47 of Set 6 | port hardy
# Processing Record 48 of Set 6 | costa rica
# Processing Record 49 of Set 6 | puerto ayora
# Processing Record 50 of Set 6 | yabelo
# Processing Record 1 of Set 7 | sur
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | jalu
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | bilma
# Processing Record 6 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 7 of Set 7 | urumqi
# Processing Record 8 of Set 7 | carnarvon
# Processing Record 9 of Set 7 | liberal
# Processing Record 10 of Set 7 | zhenlai
# Processing Record 11 of Set 7 | isangel
# Processing Record 12 of Set 7 | leningradskiy
# Processing Record 13 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 14 of Set 7 | nong phai
# Processing Record 15 of Set 7 | acarau
# Processing Record 16 of Set 7 | rio grande
# Processing Record 17 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 7 | cidreira
# Processing Record 19 of Set 7 | honningsvag
# Processing Record 20 of Set 7 | muros
# Processing Record 21 of Set 7 | arica
# Processing Record 22 of Set 7 | vestmannaeyjar
# Processing Record 23 of Set 7 | dekar
# Processing Record 24 of Set 7 | kaeo
# Processing Record 25 of Set 7 | marabba
# Processing Record 26 of Set 7 | ulety
# Processing Record 27 of Set 7 | fort smith
# Processing Record 28 of Set 7 | millinocket
# Processing Record 29 of Set 7 | itororo
# Processing Record 30 of Set 7 | asfi
# Processing Record 31 of Set 7 | saint-michel-des-saints
# Processing Record 32 of Set 7 | dayong
# Processing Record 33 of Set 7 | araouane
# Processing Record 34 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 7 | klaksvik
# Processing Record 36 of Set 7 | kaitangata
# Processing Record 37 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 7 | remontnoye
# Processing Record 39 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 7 | hambantota
# Processing Record 41 of Set 7 | benjamin constant
# Processing Record 42 of Set 7 | pundaguitan
# Processing Record 43 of Set 7 | muborak
# Processing Record 44 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 7 | lumeje
# Processing Record 46 of Set 7 | bembereke
# Processing Record 47 of Set 7 | sola
# Processing Record 48 of Set 7 | khandyga
# Processing Record 49 of Set 7 | leh
# Processing Record 50 of Set 7 | namatanai
# Processing Record 1 of Set 8 | khani
# Processing Record 2 of Set 8 | san policarpo
# Processing Record 3 of Set 8 | poum
# Processing Record 4 of Set 8 | mhlambanyatsi
# Processing Record 5 of Set 8 | la reforma
# Processing Record 6 of Set 8 | qurbah
# City not found. Skipping...
# Processing Record 7 of Set 8 | atasu
# Processing Record 8 of Set 8 | puerto pinasco
# City not found. Skipping...
# Processing Record 9 of Set 8 | bolshaya murta
# City not found. Skipping...
# Processing Record 10 of Set 8 | vestmanna
# Processing Record 11 of Set 8 | hay river
# Processing Record 12 of Set 8 | lebu
# Processing Record 13 of Set 8 | sanchor
# Processing Record 14 of Set 8 | vila do maio
# Processing Record 15 of Set 8 | matamoros
# Processing Record 16 of Set 8 | ngunguru
# Processing Record 17 of Set 8 | rosarito
# Processing Record 18 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 8 | baykit
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | vilcun
# Processing Record 22 of Set 8 | edgewater
# Processing Record 23 of Set 8 | mahibadhoo
# Processing Record 24 of Set 8 | mildura
# Processing Record 25 of Set 8 | burica
# City not found. Skipping...
# Processing Record 26 of Set 8 | bar harbor
# Processing Record 27 of Set 8 | sobolevo
# Processing Record 28 of Set 8 | iquique
# Processing Record 29 of Set 8 | trairi
# Processing Record 30 of Set 8 | touros
# Processing Record 31 of Set 8 | jining
# Processing Record 32 of Set 8 | coahuayana
# Processing Record 33 of Set 8 | opuwo
# Processing Record 34 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 8 | puqi
# Processing Record 36 of Set 8 | turinsk
# Processing Record 37 of Set 8 | seoul
# Processing Record 38 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 8 | karratha
# Processing Record 40 of Set 8 | quzhou
# Processing Record 41 of Set 8 | zlobin
# Processing Record 42 of Set 8 | ust-nera
# Processing Record 43 of Set 8 | komsomolskiy
# Processing Record 44 of Set 8 | le mars
# Processing Record 45 of Set 8 | caravelas
# Processing Record 46 of Set 8 | caranavi
# Processing Record 47 of Set 8 | pangnirtung
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | oksfjord
# Processing Record 50 of Set 8 | sao joao dos patos
# Processing Record 1 of Set 9 | broken hill
# Processing Record 2 of Set 9 | geraldton
# Processing Record 3 of Set 9 | iralaya
# Processing Record 4 of Set 9 | vikhorevka
# Processing Record 5 of Set 9 | murwillumbah
# Processing Record 6 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 9 | svetlogorsk
# Processing Record 8 of Set 9 | shahpura
# Processing Record 9 of Set 9 | havre-saint-pierre
# Processing Record 10 of Set 9 | chumikan
# Processing Record 11 of Set 9 | grand-santi
# Processing Record 12 of Set 9 | san patricio
# Processing Record 13 of Set 9 | xining
# Processing Record 14 of Set 9 | souillac
# Processing Record 15 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 9 | borovoy
# Processing Record 17 of Set 9 | mount hagen
# Processing Record 18 of Set 9 | saint pete beach
# Processing Record 19 of Set 9 | areia branca
# Processing Record 20 of Set 9 | faya
# Processing Record 21 of Set 9 | saint george
# Processing Record 22 of Set 9 | tongliao
# Processing Record 23 of Set 9 | balabac
# Processing Record 24 of Set 9 | herat
# Processing Record 25 of Set 9 | gerede
# Processing Record 26 of Set 9 | mount pleasant
# Processing Record 27 of Set 9 | rach gia
# Processing Record 28 of Set 9 | kirakira
# Processing Record 29 of Set 9 | san carlos de bariloche
# Processing Record 30 of Set 9 | xai-xai
# Processing Record 31 of Set 9 | rorvik
# Processing Record 32 of Set 9 | orocue
# Processing Record 33 of Set 9 | umm lajj
# Processing Record 34 of Set 9 | vardo
# Processing Record 35 of Set 9 | hofn
# Processing Record 36 of Set 9 | monticello
# Processing Record 37 of Set 9 | avera
# Processing Record 38 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 9 | tikrit
# Processing Record 40 of Set 9 | sibolga
# Processing Record 41 of Set 9 | konstantinovka
# Processing Record 42 of Set 9 | maceio
# Processing Record 43 of Set 9 | prince rupert
# Processing Record 44 of Set 9 | miandrivazo
# Processing Record 45 of Set 9 | eskilstuna
# Processing Record 46 of Set 9 | pingliang
# Processing Record 47 of Set 9 | kenai
# Processing Record 48 of Set 9 | biak
# Processing Record 49 of Set 9 | raga
# Processing Record 50 of Set 9 | novovoronezh
# Processing Record 1 of Set 10 | guacimo
# Processing Record 2 of Set 10 | lar
# Processing Record 3 of Set 10 | goderich
# Processing Record 4 of Set 10 | ghanzi
# Processing Record 5 of Set 10 | port blair
# Processing Record 6 of Set 10 | semnan
# Processing Record 7 of Set 10 | porto walter
# Processing Record 8 of Set 10 | finschhafen
# Processing Record 9 of Set 10 | zachary
# Processing Record 10 of Set 10 | selma
# Processing Record 11 of Set 10 | mehamn
# Processing Record 12 of Set 10 | saint-philippe
# Processing Record 13 of Set 10 | bellefontaine
# Processing Record 14 of Set 10 | havoysund
# Processing Record 15 of Set 10 | eureka
# Processing Record 16 of Set 10 | hasaki
# Processing Record 17 of Set 10 | idlib
# Processing Record 18 of Set 10 | puerto colombia
# Processing Record 19 of Set 10 | kangaatsiaq
# Processing Record 20 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 21 of Set 10 | koumac
# Processing Record 22 of Set 10 | vodnyy
# Processing Record 23 of Set 10 | nosivka
# Processing Record 24 of Set 10 | namibe
# Processing Record 25 of Set 10 | yongan
# Processing Record 26 of Set 10 | hit
# Processing Record 27 of Set 10 | saint-leu
# Processing Record 28 of Set 10 | kaseda
# Processing Record 29 of Set 10 | sao joao da barra
# Processing Record 30 of Set 10 | miri
# Processing Record 31 of Set 10 | turbat
# Processing Record 32 of Set 10 | george town
# Processing Record 33 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 10 | saint-augustin
# Processing Record 35 of Set 10 | yelizovo
# Processing Record 36 of Set 10 | yonezawa
# Processing Record 37 of Set 10 | fortuna
# Processing Record 38 of Set 10 | la primavera
# Processing Record 39 of Set 10 | hovd
# Processing Record 40 of Set 10 | tieli
# Processing Record 41 of Set 10 | coquimbo
# Processing Record 42 of Set 10 | kousseri
# Processing Record 43 of Set 10 | san quintin
# Processing Record 44 of Set 10 | sindor
# Processing Record 45 of Set 10 | auki
# Processing Record 46 of Set 10 | lata
# Processing Record 47 of Set 10 | atsiki
# City not found. Skipping...
# Processing Record 48 of Set 10 | warmbad
# Processing Record 49 of Set 10 | kahului
# Processing Record 50 of Set 10 | anakapalle
# Processing Record 1 of Set 11 | angoche
# Processing Record 2 of Set 11 | chitral
# Processing Record 3 of Set 11 | comodoro rivadavia
# Processing Record 4 of Set 11 | pasighat
# Processing Record 5 of Set 11 | novobirilyussy
# Processing Record 6 of Set 11 | nivala
# Processing Record 7 of Set 11 | den helder
# Processing Record 8 of Set 11 | melville
# Processing Record 9 of Set 11 | yatou
# Processing Record 10 of Set 11 | balagansk
# Processing Record 11 of Set 11 | guatire
# Processing Record 12 of Set 11 | hamilton
# Processing Record 13 of Set 11 | omsukchan
# Processing Record 14 of Set 11 | tsiroanomandidy
# Processing Record 15 of Set 11 | belyye stolby
# Processing Record 16 of Set 11 | talaya
# Processing Record 17 of Set 11 | ringebu
# Processing Record 18 of Set 11 | hailar
# Processing Record 19 of Set 11 | mezen
# Processing Record 20 of Set 11 | ploemeur
# Processing Record 21 of Set 11 | noumea
# Processing Record 22 of Set 11 | yuzhno-kurilsk
# Processing Record 23 of Set 11 | calafell
# Processing Record 24 of Set 11 | verkhoyansk
# Processing Record 25 of Set 11 | kodinsk
# Processing Record 26 of Set 11 | misratah
# Processing Record 27 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 28 of Set 11 | zverinogolovskoye
# Processing Record 29 of Set 11 | abay
# Processing Record 30 of Set 11 | campos gerais
# Processing Record 31 of Set 11 | montemor-o-novo
# Processing Record 32 of Set 11 | iwanai
# Processing Record 33 of Set 11 | madang
# Processing Record 34 of Set 11 | tezu
# Processing Record 35 of Set 11 | zunyi
# Processing Record 36 of Set 11 | sept-iles
# Processing Record 37 of Set 11 | nemuro
# Processing Record 38 of Set 11 | sangar
# Processing Record 39 of Set 11 | lakselv
# Processing Record 40 of Set 11 | punto fijo
# Processing Record 41 of Set 11 | amahai
# Processing Record 42 of Set 11 | mersing
# Processing Record 43 of Set 11 | kolpashevo
# Processing Record 44 of Set 11 | kasongo-lunda
# Processing Record 45 of Set 11 | heerde
# Processing Record 46 of Set 11 | vandalur
# Processing Record 47 of Set 11 | nerchinskiy zavod
# Processing Record 48 of Set 11 | nizwa
# Processing Record 49 of Set 11 | stornoway
# Processing Record 50 of Set 11 | liwale
# Processing Record 1 of Set 12 | port augusta
# Processing Record 2 of Set 12 | tilichiki
# Processing Record 3 of Set 12 | warri
# Processing Record 4 of Set 12 | waukesha
# Processing Record 5 of Set 12 | kathmandu
# Processing Record 6 of Set 12 | sirsi
# Processing Record 7 of Set 12 | port-gentil
# Processing Record 8 of Set 12 | batemans bay
# Processing Record 9 of Set 12 | mont-dore
# Processing Record 10 of Set 12 | elsfleth
# Processing Record 11 of Set 12 | charters towers
# Processing Record 12 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 13 of Set 12 | tessalit
# Processing Record 14 of Set 12 | wenling
# Processing Record 15 of Set 12 | rovaniemi
# Processing Record 16 of Set 12 | kysyl-syr
# Processing Record 17 of Set 12 | bamora
# Processing Record 18 of Set 12 | southampton
# Processing Record 19 of Set 12 | bixby
# Processing Record 20 of Set 12 | quatre cocos
# Processing Record 21 of Set 12 | uarini
# Processing Record 22 of Set 12 | zeya
# Processing Record 23 of Set 12 | balsas
# Processing Record 24 of Set 12 | charagua
# Processing Record 25 of Set 12 | bonfim
# Processing Record 26 of Set 12 | myingyan
# Processing Record 27 of Set 12 | petropavlovka
# Processing Record 28 of Set 12 | kamenka
# Processing Record 29 of Set 12 | koutsouras
# Processing Record 30 of Set 12 | rutul
# Processing Record 31 of Set 12 | price
# Processing Record 32 of Set 12 | aloleng
# Processing Record 33 of Set 12 | agadez
# Processing Record 34 of Set 12 | bilibino
# Processing Record 35 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 12 | natchitoches
# Processing Record 37 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 12 | benguela
# Processing Record 39 of Set 12 | fukue
# Processing Record 40 of Set 12 | montepuez
# Processing Record 41 of Set 12 | olafsvik
# Processing Record 42 of Set 12 | kanniyakumari
# Processing Record 43 of Set 12 | lahti
# Processing Record 44 of Set 12 | iqaluit
# Processing Record 45 of Set 12 | mombetsu
# Processing Record 46 of Set 12 | chapais
# Processing Record 47 of Set 12 | apatou
# Processing Record 48 of Set 12 | maxixe
# Processing Record 49 of Set 12 | thurso
# Processing Record 50 of Set 12 | poopo
# Processing Record 1 of Set 13 | guelph
# Processing Record 2 of Set 13 | coos bay
# Processing Record 3 of Set 13 | merritt
# Processing Record 4 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 5 of Set 13 | lichinga
# Processing Record 6 of Set 13 | bolekhiv
# Processing Record 7 of Set 13 | kedrovyy
# Processing Record 8 of Set 13 | road town
# Processing Record 9 of Set 13 | yonibana
# Processing Record 10 of Set 13 | togur
# Processing Record 11 of Set 13 | syracuse
# Processing Record 12 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 13 | nantucket
# Processing Record 14 of Set 13 | shibetsu
# Processing Record 15 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 16 of Set 13 | agua prieta
# Processing Record 17 of Set 13 | diamantino
# Processing Record 18 of Set 13 | jiangyou
# Processing Record 19 of Set 13 | bouake
# Processing Record 20 of Set 13 | boueni
# Processing Record 21 of Set 13 | rio grande city
# Processing Record 22 of Set 13 | altay
# Processing Record 23 of Set 13 | baraki barak
# Processing Record 24 of Set 13 | kununurra
# Processing Record 25 of Set 13 | kyzyl-mazhalyk
# Processing Record 26 of Set 13 | kaputa
# Processing Record 27 of Set 13 | khon buri
# Processing Record 28 of Set 13 | mandiana
# Processing Record 29 of Set 13 | kimbe
# Processing Record 30 of Set 13 | fomboni
# Processing Record 31 of Set 13 | dolores
# Processing Record 32 of Set 13 | kvarkeno
# Processing Record 33 of Set 13 | ekibastuz
# Processing Record 34 of Set 13 | saint anthony
# Processing Record 35 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 13 | gusau
# Processing Record 37 of Set 13 | youhao
# Processing Record 38 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 13 | novoye atlashevo
# City not found. Skipping...
# Processing Record 40 of Set 13 | townsville
# Processing Record 41 of Set 13 | kiama
# Processing Record 42 of Set 13 | nador
# Processing Record 43 of Set 13 | goundam
# Processing Record 44 of Set 13 | shunyi
# Processing Record 45 of Set 13 | kieta
# Processing Record 46 of Set 13 | tornio
# Processing Record 47 of Set 13 | warrnambool
# Processing Record 48 of Set 13 | chifeng
# Processing Record 49 of Set 13 | pueblo nuevo
# Processing Record 50 of Set 13 | marsh harbour
# Processing Record 1 of Set 14 | melendugno
# Processing Record 2 of Set 14 | petauke
# Processing Record 3 of Set 14 | kalevala
# Processing Record 4 of Set 14 | najran
# Processing Record 5 of Set 14 | lisakovsk
# Processing Record 6 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 14 | rawson
# Processing Record 8 of Set 14 | turinskaya sloboda
# Processing Record 9 of Set 14 | vila
# Processing Record 10 of Set 14 | kabinda
# Processing Record 11 of Set 14 | cap malheureux
# Processing Record 12 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 14 | tapiramuta
# Processing Record 14 of Set 14 | dongsheng
# Processing Record 15 of Set 14 | beringovskiy
# Processing Record 16 of Set 14 | necochea
# Processing Record 17 of Set 14 | lira
# Processing Record 18 of Set 14 | neustadt
# Processing Record 19 of Set 14 | rapid city
# Processing Record 20 of Set 14 | sampang
# Processing Record 21 of Set 14 | pinillos
# Processing Record 22 of Set 14 | beidao
# Processing Record 23 of Set 14 | emilio carranza
# Processing Record 24 of Set 14 | iraucuba
# Processing Record 25 of Set 14 | ossora
# Processing Record 26 of Set 14 | lagos
# Processing Record 27 of Set 14 | changli
# Processing Record 28 of Set 14 | zhangye
# Processing Record 29 of Set 14 | miles city
# Processing Record 30 of Set 14 | laterza
# Processing Record 31 of Set 14 | san felice sul panaro
# Processing Record 32 of Set 14 | kuusamo
# Processing Record 33 of Set 14 | ust-ilimsk
# Processing Record 34 of Set 14 | kavieng
# Processing Record 35 of Set 14 | manica
# Processing Record 36 of Set 14 | mount isa
# Processing Record 37 of Set 14 | carmarthen
# Processing Record 38 of Set 14 | flinders
# Processing Record 39 of Set 14 | saint-joseph
# Processing Record 40 of Set 14 | batyrevo
# Processing Record 41 of Set 14 | dutse
# Processing Record 42 of Set 14 | sand springs
# Processing Record 43 of Set 14 | cukai
# Processing Record 44 of Set 14 | cockburn town
# Processing Record 45 of Set 14 | mbini
# Processing Record 46 of Set 14 | yilan
# Processing Record 47 of Set 14 | rocha
# Processing Record 48 of Set 14 | zvishavane
# Processing Record 49 of Set 14 | puerto escondido
# Processing Record 50 of Set 14 | lampazos de naranjo
# Processing Record 1 of Set 15 | raudeberg
# Processing Record 2 of Set 15 | beira
# Processing Record 3 of Set 15 | general pico
# Processing Record 4 of Set 15 | soyo
# Processing Record 5 of Set 15 | antalaha
# Processing Record 6 of Set 15 | gavle
# Processing Record 7 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 15 | itarema
# Processing Record 9 of Set 15 | mancora
# Processing Record 10 of Set 15 | belinskiy
# Processing Record 11 of Set 15 | yekaterinoslavka
# Processing Record 12 of Set 15 | surgut
# Processing Record 13 of Set 15 | aligudarz
# Processing Record 14 of Set 15 | asmar
# Processing Record 15 of Set 15 | svetlyy
# Processing Record 16 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 15 | raxaul
# Processing Record 18 of Set 15 | kovur
# Processing Record 19 of Set 15 | jumla
# Processing Record 20 of Set 15 | talcahuano
# Processing Record 21 of Set 15 | bambanglipuro
# Processing Record 22 of Set 15 | sheridan
# Processing Record 23 of Set 15 | aklavik
# Processing Record 24 of Set 15 | pandan
# Processing Record 25 of Set 15 | pokhara
# Processing Record 26 of Set 15 | ternate
# Processing Record 27 of Set 15 | the valley
# Processing Record 28 of Set 15 | puerto madryn
# Processing Record 29 of Set 15 | krasnovishersk
# Processing Record 30 of Set 15 | mayen
# Processing Record 31 of Set 15 | duku
# Processing Record 32 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 33 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 15 | glenwood springs
# Processing Record 35 of Set 15 | konotop
# Processing Record 36 of Set 15 | fare
# Processing Record 37 of Set 15 | suntar
# Processing Record 38 of Set 15 | nabire
# Processing Record 39 of Set 15 | risalpur
# Processing Record 40 of Set 15 | marau
# Processing Record 41 of Set 15 | srednekolymsk
# Processing Record 42 of Set 15 | zhicheng
# Processing Record 43 of Set 15 | surt
# Processing Record 44 of Set 15 | fort nelson
# Processing Record 45 of Set 15 | sovetskiy
# Processing Record 46 of Set 15 | christchurch
# Processing Record 47 of Set 15 | bonavista
# Processing Record 48 of Set 15 | katherine
# Processing Record 49 of Set 15 | puyo
# Processing Record 50 of Set 15 | kasempa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the arry of dictonaries to a pandas Dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Clyde River      CA  70.4692  -68.5914     -5.57        77         100
# 1          Kyaikto      MM  17.3000   97.0167     67.86        67           3
# 2     Constitucion      CL -35.3333  -72.4167     66.24        71          21
# 3           Albany      US  42.6001  -73.9662     37.99        89         100
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     71.56        88         100
# 5           Lompoc      US  34.6391 -120.4579     70.79        70           0
# 6           Castro      BR -24.7911  -50.0119     64.08        76         100
# 7          Ushuaia      AR -54.8000  -68.3000     46.06        61         100
# 8   Santa Quiteria      BR  -4.3319  -40.1567     83.23        39          94
# 9            Lagoa      PT  39.0500  -27.9833     59.74        72         100
#
#    Wind Speed      Current Description
# 0       32.21               light snow
# 1        3.56                clear sky
# 2        8.25               few clouds
# 3        1.01          overcast clouds
# 4        2.30  light intensity drizzle
# 5       10.36                clear sky
# 6        9.10          overcast clouds
# 7       12.66          overcast clouds
# 8        4.03          overcast clouds
# 9       10.69          overcast clouds

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("/Users/khagenkadariya/World_Weather_Analysis/Weather_data/WeatherPy_database.csv")
